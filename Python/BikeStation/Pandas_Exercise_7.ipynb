# %% [markdown]
# # Read CSV

# %%
import pandas as pd

# %%
dataframe = pd.read_csv(r'C:\Users\Balajisri\Downloads\WHO-COVID-19-global-data.csv')

# %% [markdown]
# # head and tail

# %%
dataframe.head()
# Out:
#   Date_reported  Country_code      Country  WHO_region   New_cases  \
# 0      1/3/2020            AF  Afghanistan        EMRO           0
# 1      1/4/2020            AF  Afghanistan        EMRO           0
# 2      1/5/2020            AF  Afghanistan        EMRO           0
# 3      1/6/2020            AF  Afghanistan        EMRO           0
# 4      1/7/2020            AF  Afghanistan        EMRO           0
#
#     Cumulative_cases   New_deaths   Cumulative_deaths
# 0                  0            0                   0
# 1                  0            0                   0
# 2                  0            0                   0
# 3                  0            0                   0
# 4                  0            0                   0

# %%
dataframe.tail()
# Out:
#       Date_reported  Country_code   Country  WHO_region   New_cases  \
# 69320    10/19/2020            ZW  Zimbabwe        AFRO          37
# 69321    10/20/2020            ZW  Zimbabwe        AFRO          12
# 69322    10/21/2020            ZW  Zimbabwe        AFRO          28
# 69323    10/22/2020            ZW  Zimbabwe        AFRO          28
# 69324    10/23/2020            ZW  Zimbabwe        AFRO          27
#
#         Cumulative_cases   New_deaths   Cumulative_deaths
# 69320               8147            0                 231
# 69321               8159            1                 232
# 69322               8187            1                 233
# 69323               8215            3                 236
# 69324               8242            0                 236

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69325 entries, 0 to 69324
# Data columns (total 8 columns):
# Date_reported         69325 non-null object
#  Country_code         69030 non-null object
#  Country              69325 non-null object
#  WHO_region           69325 non-null object
#  New_cases            69325 non-null int64
#  Cumulative_cases     69325 non-null int64
#  New_deaths           69325 non-null int64
#  Cumulative_deaths    69325 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 4.2+ MB

# %%
dataframe.columns
# Out:
# Index(['Date_reported', ' Country_code', ' Country', ' WHO_region',
#        ' New_cases', ' Cumulative_cases', ' New_deaths', ' Cumulative_deaths'],
#       dtype='object')

# %%
dataframe.reset_index()
# Out:
#        index Date_reported  Country_code      Country  WHO_region   New_cases  \
# 0          0      1/3/2020            AF  Afghanistan        EMRO           0
# 1          1      1/4/2020            AF  Afghanistan        EMRO           0
# 2          2      1/5/2020            AF  Afghanistan        EMRO           0
# 3          3      1/6/2020            AF  Afghanistan        EMRO           0
# 4          4      1/7/2020            AF  Afghanistan        EMRO           0
# 5          5      1/8/2020            AF  Afghanistan        EMRO           0
# 6          6      1/9/2020            AF  Afghanistan        EMRO           0
# 7          7     1/10/2020            AF  Afghanistan        EMRO           0
# 8          8     1/11/2020            AF  Afghanistan        EMRO           0
# 9          9     1/12/2020            AF  Afghanistan        EMRO           0
# 10        10     1/13/2020            AF  Afghanistan        EMRO           0
# ...

# %% [markdown]
# # Describe

# %%
dataframe.describe()
# Out:
#           New_cases   Cumulative_cases    New_deaths   Cumulative_deaths
# count  69325.000000       6.932500e+04  69325.000000        69325.000000
# mean     599.652117       4.718867e+04     16.371295         1744.411266
# std     4072.663479       3.456955e+05    108.507339        10708.014096
# min    -8261.000000       0.000000e+00   -514.000000            0.000000
# 25%        0.000000       0.000000e+00      0.000000            0.000000
# 50%        0.000000       2.400000e+02      0.000000            4.000000
# 75%       73.000000       5.669000e+03      1.000000          108.000000
# max    97894.000000       8.248149e+06   6409.000000       220563.000000

# %% [markdown]
# # Sorting

# %%
dataframe.sort_values(by = [' Cumulative_deaths'])
# Out:
#       Date_reported  Country_code                   Country  WHO_region  \
# 0          1/3/2020            AF               Afghanistan        EMRO
# 39298      3/6/2020            YT                   Mayotte        AFRO
# 39299      3/7/2020            YT                   Mayotte        AFRO
# 39300      3/8/2020            YT                   Mayotte        AFRO
# 39301      3/9/2020            YT                   Mayotte        AFRO
# 39302     3/10/2020            YT                   Mayotte        AFRO
# 39303     3/11/2020            YT                   Mayotte        AFRO
# 39304     3/12/2020            YT                   Mayotte        AFRO
# 39297      3/5/2020            YT                   Mayotte        AFRO
# 39305     3/13/2020            YT                   Mayotte        AFRO
# 39307     3/15/2020            YT                   Mayotte        AFRO
# 39308     3/16/2020            YT                   Mayotte        AFRO
# ...

# %%
dataframe[' New_cases'].max()
# Out:
# 97894

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import random
import tensorflow as tf
from pathlib import Path
from tensorflow.keras import applications
from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import optimizers
from tensorflow.keras import metrics
from tensorflow.keras import Model
from tensorflow.keras.applications import vgg16


target_shape = (96, 96)

# %%
cache_dir = "D:\BigDataScience\Document"
anchor_images_path = cache_dir + "/anchor"
positive_images_path = cache_dir + "/positive"

# %%
def preprocess_image(filename):
    """
    Load the specified file as a JPEG image, preprocess it and
    resize it to the target shape.
    """

    image_string = tf.io.read_file(filename)
    image = tf.image.decode_jpeg(image_string, channels=3)
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, target_shape)
    return image


def preprocess_triplets(anchor, positive, negative):
    """
    Given the filenames corresponding to the three images, load and
    preprocess them.
    """

    return (
        preprocess_image(anchor),
        preprocess_image(positive),
        preprocess_image(negative),
    )

# %%
anchor_images = sorted(
    [str(anchor_images_path +'/'+ f) for f in os.listdir(anchor_images_path)]
)

positive_images = sorted(
    [str(positive_images_path +'/'+ f) for f in os.listdir(positive_images_path)]
)

# %%
anchor_images
# Out:
# ['D:\\BigDataScience\\Document/anchor/A (1).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (10).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (11).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (12).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (13).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (14).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (15).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (16).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (17).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (18).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (19).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (2).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (20).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (21).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (22).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (23).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (24).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (25).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (26).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (27).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (28).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (29).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (3).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (30).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (31).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (32).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (4).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (5).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (6).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (7).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (8).jpg',
#  'D:\\BigDataScience\\Document/anchor/A (9).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (1).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (10).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (11).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (12).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (13).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (14).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (15).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (16).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (17).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (18).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (19).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (2).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (20).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (21).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (22).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (23).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (24).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (25).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (26).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (27).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (28).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (29).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (3).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (30).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (31).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (32).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (4).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (5).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (6).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (7).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (8).jpg',
#  'D:\\BigDataScience\\Document/anchor/B (9).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (1).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (10).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (11).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (12).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (13).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (14).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (15).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (16).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (17).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (18).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (19).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (2).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (20).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (21).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (22).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (23).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (24).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (25).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (26).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (27).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (28).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (29).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (3).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (30).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (31).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (32).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (4).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (5).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (6).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (7).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (8).jpg',
#  'D:\\BigDataScience\\Document/anchor/C (9).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (1).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (10).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (11).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (12).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (13).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (14).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (15).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (16).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (17).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (18).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (19).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (2).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (20).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (21).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (22).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (23).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (24).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (25).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (26).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (27).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (28).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (29).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (3).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (30).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (31).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (32).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (4).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (5).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (6).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (7).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (8).jpg',
#  'D:\\BigDataScience\\Document/anchor/D (9).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (1).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (10).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (11).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (12).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (13).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (14).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (15).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (16).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (17).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (18).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (19).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (2).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (20).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (21).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (22).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (23).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (24).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (25).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (26).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (27).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (28).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (29).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (3).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (30).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (31).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (32).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (4).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (5).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (6).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (7).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (8).jpg',
#  'D:\\BigDataScience\\Document/anchor/E (9).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (1).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (10).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (11).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (12).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (13).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (14).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (15).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (16).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (17).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (18).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (19).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (2).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (20).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (21).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (22).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (23).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (24).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (25).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (26).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (27).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (28).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (29).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (3).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (30).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (31).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (32).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (4).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (5).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (6).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (7).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (8).jpg',
#  'D:\\BigDataScience\\Document/anchor/F (9).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (1).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (10).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (11).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (12).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (13).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (14).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (15).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (16).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (17).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (18).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (19).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (2).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (20).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (21).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (22).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (23).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (24).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (25).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (26).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (27).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (28).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (29).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (3).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (30).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (31).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (32).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (4).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (5).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (6).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (7).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (8).jpg',
#  'D:\\BigDataScience\\Document/anchor/G (9).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (1).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (10).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (11).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (12).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (13).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (14).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (15).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (16).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (17).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (18).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (19).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (2).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (20).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (21).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (22).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (23).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (24).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (25).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (26).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (27).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (28).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (29).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (3).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (30).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (31).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (32).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (4).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (5).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (6).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (7).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (8).jpg',
#  'D:\\BigDataScience\\Document/anchor/H (9).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (1).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (10).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (11).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (12).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (13).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (14).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (15).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (16).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (17).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (18).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (19).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (2).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (20).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (21).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (22).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (23).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (24).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (25).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (26).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (27).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (28).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (29).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (3).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (30).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (31).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (32).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (4).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (5).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (6).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (7).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (8).jpg',
#  'D:\\BigDataScience\\Document/anchor/I (9).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (1).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (10).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (11).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (12).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (13).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (14).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (15).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (16).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (17).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (18).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (19).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (2).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (20).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (21).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (22).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (23).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (24).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (25).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (26).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (27).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (28).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (29).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (3).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (30).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (31).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (32).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (4).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (5).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (6).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (7).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (8).jpg',
#  'D:\\BigDataScience\\Document/anchor/K (9).jpg']

# %%
positive_images
# Out:
# ['D:\\BigDataScience\\Document/positive/A (1).jpg',
#  'D:\\BigDataScience\\Document/positive/A (10).jpg',
#  'D:\\BigDataScience\\Document/positive/A (11).jpg',
#  'D:\\BigDataScience\\Document/positive/A (12).jpg',
#  'D:\\BigDataScience\\Document/positive/A (13).jpg',
#  'D:\\BigDataScience\\Document/positive/A (14).jpg',
#  'D:\\BigDataScience\\Document/positive/A (15).jpg',
#  'D:\\BigDataScience\\Document/positive/A (16).jpg',
#  'D:\\BigDataScience\\Document/positive/A (17).jpg',
#  'D:\\BigDataScience\\Document/positive/A (18).jpg',
#  'D:\\BigDataScience\\Document/positive/A (19).jpg',
#  'D:\\BigDataScience\\Document/positive/A (2).jpg',
#  'D:\\BigDataScience\\Document/positive/A (20).jpg',
#  'D:\\BigDataScience\\Document/positive/A (21).jpg',
#  'D:\\BigDataScience\\Document/positive/A (22).jpg',
#  'D:\\BigDataScience\\Document/positive/A (23).jpg',
#  'D:\\BigDataScience\\Document/positive/A (24).jpg',
#  'D:\\BigDataScience\\Document/positive/A (25).jpg',
#  'D:\\BigDataScience\\Document/positive/A (26).jpg',
#  'D:\\BigDataScience\\Document/positive/A (27).jpg',
#  'D:\\BigDataScience\\Document/positive/A (28).jpg',
#  'D:\\BigDataScience\\Document/positive/A (29).jpg',
#  'D:\\BigDataScience\\Document/positive/A (3).jpg',
#  'D:\\BigDataScience\\Document/positive/A (30).jpg',
#  'D:\\BigDataScience\\Document/positive/A (31).jpg',
#  'D:\\BigDataScience\\Document/positive/A (32).jpg',
#  'D:\\BigDataScience\\Document/positive/A (4).jpg',
#  'D:\\BigDataScience\\Document/positive/A (5).jpg',
#  'D:\\BigDataScience\\Document/positive/A (6).jpg',
#  'D:\\BigDataScience\\Document/positive/A (7).jpg',
#  'D:\\BigDataScience\\Document/positive/A (8).jpg',
#  'D:\\BigDataScience\\Document/positive/A (9).jpg',
#  'D:\\BigDataScience\\Document/positive/B (1).jpg',
#  'D:\\BigDataScience\\Document/positive/B (33).jpg',
#  'D:\\BigDataScience\\Document/positive/B (34).jpg',
#  'D:\\BigDataScience\\Document/positive/B (35).jpg',
#  'D:\\BigDataScience\\Document/positive/B (36).jpg',
#  'D:\\BigDataScience\\Document/positive/B (37).jpg',
#  'D:\\BigDataScience\\Document/positive/B (38).jpg',
#  'D:\\BigDataScience\\Document/positive/B (39).jpg',
#  'D:\\BigDataScience\\Document/positive/B (40).jpg',
#  'D:\\BigDataScience\\Document/positive/B (41).jpg',
#  'D:\\BigDataScience\\Document/positive/B (42).jpg',
#  'D:\\BigDataScience\\Document/positive/B (43).jpg',
#  'D:\\BigDataScience\\Document/positive/B (44).jpg',
#  'D:\\BigDataScience\\Document/positive/B (45).jpg',
#  'D:\\BigDataScience\\Document/positive/B (46).jpg',
#  'D:\\BigDataScience\\Document/positive/B (47).jpg',
#  'D:\\BigDataScience\\Document/positive/B (48).jpg',
#  'D:\\BigDataScience\\Document/positive/B (49).jpg',
#  'D:\\BigDataScience\\Document/positive/B (50).jpg',
#  'D:\\BigDataScience\\Document/positive/B (51).jpg',
#  'D:\\BigDataScience\\Document/positive/B (52).jpg',
#  'D:\\BigDataScience\\Document/positive/B (53).jpg',
#  'D:\\BigDataScience\\Document/positive/B (54).jpg',
#  'D:\\BigDataScience\\Document/positive/B (55).jpg',
#  'D:\\BigDataScience\\Document/positive/B (56).jpg',
#  'D:\\BigDataScience\\Document/positive/B (57).jpg',
#  'D:\\BigDataScience\\Document/positive/B (58).jpg',
#  'D:\\BigDataScience\\Document/positive/B (59).jpg',
#  'D:\\BigDataScience\\Document/positive/B (60).jpg',
#  'D:\\BigDataScience\\Document/positive/B (61).jpg',
#  'D:\\BigDataScience\\Document/positive/B (62).jpg',
#  'D:\\BigDataScience\\Document/positive/B (63).jpg',
#  'D:\\BigDataScience\\Document/positive/C (1).jpg',
#  'D:\\BigDataScience\\Document/positive/C (10).jpg',
#  'D:\\BigDataScience\\Document/positive/C (11).jpg',
#  'D:\\BigDataScience\\Document/positive/C (12).jpg',
#  'D:\\BigDataScience\\Document/positive/C (13).jpg',
#  'D:\\BigDataScience\\Document/positive/C (14).jpg',
#  'D:\\BigDataScience\\Document/positive/C (15).jpg',
#  'D:\\BigDataScience\\Document/positive/C (16).jpg',
#  'D:\\BigDataScience\\Document/positive/C (17).jpg',
#  'D:\\BigDataScience\\Document/positive/C (18).jpg',
#  'D:\\BigDataScience\\Document/positive/C (19).jpg',
#  'D:\\BigDataScience\\Document/positive/C (2).jpg',
#  'D:\\BigDataScience\\Document/positive/C (20).jpg',
#  'D:\\BigDataScience\\Document/positive/C (21).jpg',
#  'D:\\BigDataScience\\Document/positive/C (22).jpg',
#  'D:\\BigDataScience\\Document/positive/C (23).jpg',
#  'D:\\BigDataScience\\Document/positive/C (24).jpg',
#  'D:\\BigDataScience\\Document/positive/C (25).jpg',
#  'D:\\BigDataScience\\Document/positive/C (26).jpg',
#  'D:\\BigDataScience\\Document/positive/C (27).jpg',
#  'D:\\BigDataScience\\Document/positive/C (28).jpg',
#  'D:\\BigDataScience\\Document/positive/C (29).jpg',
#  'D:\\BigDataScience\\Document/positive/C (3).jpg',
#  'D:\\BigDataScience\\Document/positive/C (30).jpg',
#  'D:\\BigDataScience\\Document/positive/C (31).jpg',
#  'D:\\BigDataScience\\Document/positive/C (32).jpg',
#  'D:\\BigDataScience\\Document/positive/C (4).jpg',
#  'D:\\BigDataScience\\Document/positive/C (5).jpg',
#  'D:\\BigDataScience\\Document/positive/C (6).jpg',
#  'D:\\BigDataScience\\Document/positive/C (7).jpg',
#  'D:\\BigDataScience\\Document/positive/C (8).jpg',
#  'D:\\BigDataScience\\Document/positive/C (9).jpg',
#  'D:\\BigDataScience\\Document/positive/D (1).jpg',
#  'D:\\BigDataScience\\Document/positive/D (10).jpg',
#  'D:\\BigDataScience\\Document/positive/D (11).jpg',
#  'D:\\BigDataScience\\Document/positive/D (12).jpg',
#  'D:\\BigDataScience\\Document/positive/D (13).jpg',
#  'D:\\BigDataScience\\Document/positive/D (14).jpg',
#  'D:\\BigDataScience\\Document/positive/D (15).jpg',
#  'D:\\BigDataScience\\Document/positive/D (16).jpg',
#  'D:\\BigDataScience\\Document/positive/D (17).jpg',
#  'D:\\BigDataScience\\Document/positive/D (18).jpg',
#  'D:\\BigDataScience\\Document/positive/D (19).jpg',
#  'D:\\BigDataScience\\Document/positive/D (2).jpg',
#  'D:\\BigDataScience\\Document/positive/D (20).jpg',
#  'D:\\BigDataScience\\Document/positive/D (21).jpg',
#  'D:\\BigDataScience\\Document/positive/D (22).jpg',
#  'D:\\BigDataScience\\Document/positive/D (23).jpg',
#  'D:\\BigDataScience\\Document/positive/D (24).jpg',
#  'D:\\BigDataScience\\Document/positive/D (25).jpg',
#  'D:\\BigDataScience\\Document/positive/D (26).jpg',
#  'D:\\BigDataScience\\Document/positive/D (27).jpg',
#  'D:\\BigDataScience\\Document/positive/D (28).jpg',
#  'D:\\BigDataScience\\Document/positive/D (29).jpg',
#  'D:\\BigDataScience\\Document/positive/D (3).jpg',
#  'D:\\BigDataScience\\Document/positive/D (30).jpg',
#  'D:\\BigDataScience\\Document/positive/D (31).jpg',
#  'D:\\BigDataScience\\Document/positive/D (32).jpg',
#  'D:\\BigDataScience\\Document/positive/D (4).jpg',
#  'D:\\BigDataScience\\Document/positive/D (5).jpg',
#  'D:\\BigDataScience\\Document/positive/D (6).jpg',
#  'D:\\BigDataScience\\Document/positive/D (7).jpg',
#  'D:\\BigDataScience\\Document/positive/D (8).jpg',
#  'D:\\BigDataScience\\Document/positive/D (9).jpg',
#  'D:\\BigDataScience\\Document/positive/E (1).jpg',
#  'D:\\BigDataScience\\Document/positive/E (10).jpg',
#  'D:\\BigDataScience\\Document/positive/E (11).jpg',
#  'D:\\BigDataScience\\Document/positive/E (12).jpg',
#  'D:\\BigDataScience\\Document/positive/E (13).jpg',
#  'D:\\BigDataScience\\Document/positive/E (14).jpg',
#  'D:\\BigDataScience\\Document/positive/E (15).jpg',
#  'D:\\BigDataScience\\Document/positive/E (16).jpg',
#  'D:\\BigDataScience\\Document/positive/E (17).jpg',
#  'D:\\BigDataScience\\Document/positive/E (18).jpg',
#  'D:\\BigDataScience\\Document/positive/E (19).jpg',
#  'D:\\BigDataScience\\Document/positive/E (2).jpg',
#  'D:\\BigDataScience\\Document/positive/E (20).jpg',
#  'D:\\BigDataScience\\Document/positive/E (21).jpg',
#  'D:\\BigDataScience\\Document/positive/E (22).jpg',
#  'D:\\BigDataScience\\Document/positive/E (23).jpg',
#  'D:\\BigDataScience\\Document/positive/E (24).jpg',
#  'D:\\BigDataScience\\Document/positive/E (25).jpg',
#  'D:\\BigDataScience\\Document/positive/E (26).jpg',
#  'D:\\BigDataScience\\Document/positive/E (27).jpg',
#  'D:\\BigDataScience\\Document/positive/E (28).jpg',
#  'D:\\BigDataScience\\Document/positive/E (29).jpg',
#  'D:\\BigDataScience\\Document/positive/E (3).jpg',
#  'D:\\BigDataScience\\Document/positive/E (30).jpg',
#  'D:\\BigDataScience\\Document/positive/E (31).jpg',
#  'D:\\BigDataScience\\Document/positive/E (32).jpg',
#  'D:\\BigDataScience\\Document/positive/E (4).jpg',
#  'D:\\BigDataScience\\Document/positive/E (5).jpg',
#  'D:\\BigDataScience\\Document/positive/E (6).jpg',
#  'D:\\BigDataScience\\Document/positive/E (7).jpg',
#  'D:\\BigDataScience\\Document/positive/E (8).jpg',
#  'D:\\BigDataScience\\Document/positive/E (9).jpg',
#  'D:\\BigDataScience\\Document/positive/F (1).jpg',
#  'D:\\BigDataScience\\Document/positive/F (10).jpg',
#  'D:\\BigDataScience\\Document/positive/F (11).jpg',
#  'D:\\BigDataScience\\Document/positive/F (12).jpg',
#  'D:\\BigDataScience\\Document/positive/F (13).jpg',
#  'D:\\BigDataScience\\Document/positive/F (14).jpg',
#  'D:\\BigDataScience\\Document/positive/F (15).jpg',
#  'D:\\BigDataScience\\Document/positive/F (16).jpg',
#  'D:\\BigDataScience\\Document/positive/F (17).jpg',
#  'D:\\BigDataScience\\Document/positive/F (18).jpg',
#  'D:\\BigDataScience\\Document/positive/F (19).jpg',
#  'D:\\BigDataScience\\Document/positive/F (2).jpg',
#  'D:\\BigDataScience\\Document/positive/F (20).jpg',
#  'D:\\BigDataScience\\Document/positive/F (21).jpg',
#  'D:\\BigDataScience\\Document/positive/F (22).jpg',
#  'D:\\BigDataScience\\Document/positive/F (23).jpg',
#  'D:\\BigDataScience\\Document/positive/F (24).jpg',
#  'D:\\BigDataScience\\Document/positive/F (25).jpg',
#  'D:\\BigDataScience\\Document/positive/F (26).jpg',
#  'D:\\BigDataScience\\Document/positive/F (27).jpg',
#  'D:\\BigDataScience\\Document/positive/F (28).jpg',
#  'D:\\BigDataScience\\Document/positive/F (29).jpg',
#  'D:\\BigDataScience\\Document/positive/F (3).jpg',
#  'D:\\BigDataScience\\Document/positive/F (30).jpg',
#  'D:\\BigDataScience\\Document/positive/F (31).jpg',
#  'D:\\BigDataScience\\Document/positive/F (32).jpg',
#  'D:\\BigDataScience\\Document/positive/F (4).jpg',
#  'D:\\BigDataScience\\Document/positive/F (5).jpg',
#  'D:\\BigDataScience\\Document/positive/F (6).jpg',
#  'D:\\BigDataScience\\Document/positive/F (7).jpg',
#  'D:\\BigDataScience\\Document/positive/F (8).jpg',
#  'D:\\BigDataScience\\Document/positive/F (9).jpg',
#  'D:\\BigDataScience\\Document/positive/G (1).jpg',
#  'D:\\BigDataScience\\Document/positive/G (10).jpg',
#  'D:\\BigDataScience\\Document/positive/G (11).jpg',
#  'D:\\BigDataScience\\Document/positive/G (12).jpg',
#  'D:\\BigDataScience\\Document/positive/G (13).jpg',
#  'D:\\BigDataScience\\Document/positive/G (14).jpg',
#  'D:\\BigDataScience\\Document/positive/G (15).jpg',
#  'D:\\BigDataScience\\Document/positive/G (16).jpg',
#  'D:\\BigDataScience\\Document/positive/G (17).jpg',
#  'D:\\BigDataScience\\Document/positive/G (18).jpg',
#  'D:\\BigDataScience\\Document/positive/G (19).jpg',
#  'D:\\BigDataScience\\Document/positive/G (2).jpg',
#  'D:\\BigDataScience\\Document/positive/G (20).jpg',
#  'D:\\BigDataScience\\Document/positive/G (21).jpg',
#  'D:\\BigDataScience\\Document/positive/G (22).jpg',
#  'D:\\BigDataScience\\Document/positive/G (23).jpg',
#  'D:\\BigDataScience\\Document/positive/G (24).jpg',
#  'D:\\BigDataScience\\Document/positive/G (25).jpg',
#  'D:\\BigDataScience\\Document/positive/G (26).jpg',
#  'D:\\BigDataScience\\Document/positive/G (27).jpg',
#  'D:\\BigDataScience\\Document/positive/G (28).jpg',
#  'D:\\BigDataScience\\Document/positive/G (29).jpg',
#  'D:\\BigDataScience\\Document/positive/G (3).jpg',
#  'D:\\BigDataScience\\Document/positive/G (30).jpg',
#  'D:\\BigDataScience\\Document/positive/G (31).jpg',
#  'D:\\BigDataScience\\Document/positive/G (32).jpg',
#  'D:\\BigDataScience\\Document/positive/G (4).jpg',
#  'D:\\BigDataScience\\Document/positive/G (5).jpg',
#  'D:\\BigDataScience\\Document/positive/G (6).jpg',
#  'D:\\BigDataScience\\Document/positive/G (7).jpg',
#  'D:\\BigDataScience\\Document/positive/G (8).jpg',
#  'D:\\BigDataScience\\Document/positive/G (9).jpg',
#  'D:\\BigDataScience\\Document/positive/H (1).jpg',
#  'D:\\BigDataScience\\Document/positive/H (10).jpg',
#  'D:\\BigDataScience\\Document/positive/H (11).jpg',
#  'D:\\BigDataScience\\Document/positive/H (12).jpg',
#  'D:\\BigDataScience\\Document/positive/H (13).jpg',
#  'D:\\BigDataScience\\Document/positive/H (14).jpg',
#  'D:\\BigDataScience\\Document/positive/H (15).jpg',
#  'D:\\BigDataScience\\Document/positive/H (16).jpg',
#  'D:\\BigDataScience\\Document/positive/H (17).jpg',
#  'D:\\BigDataScience\\Document/positive/H (18).jpg',
#  'D:\\BigDataScience\\Document/positive/H (19).jpg',
#  'D:\\BigDataScience\\Document/positive/H (2).jpg',
#  'D:\\BigDataScience\\Document/positive/H (20).jpg',
#  'D:\\BigDataScience\\Document/positive/H (21).jpg',
#  'D:\\BigDataScience\\Document/positive/H (22).jpg',
#  'D:\\BigDataScience\\Document/positive/H (23).jpg',
#  'D:\\BigDataScience\\Document/positive/H (24).jpg',
#  'D:\\BigDataScience\\Document/positive/H (25).jpg',
#  'D:\\BigDataScience\\Document/positive/H (26).jpg',
#  'D:\\BigDataScience\\Document/positive/H (27).jpg',
#  'D:\\BigDataScience\\Document/positive/H (28).jpg',
#  'D:\\BigDataScience\\Document/positive/H (29).jpg',
#  'D:\\BigDataScience\\Document/positive/H (3).jpg',
#  'D:\\BigDataScience\\Document/positive/H (30).jpg',
#  'D:\\BigDataScience\\Document/positive/H (31).jpg',
#  'D:\\BigDataScience\\Document/positive/H (32).jpg',
#  'D:\\BigDataScience\\Document/positive/H (4).jpg',
#  'D:\\BigDataScience\\Document/positive/H (5).jpg',
#  'D:\\BigDataScience\\Document/positive/H (6).jpg',
#  'D:\\BigDataScience\\Document/positive/H (7).jpg',
#  'D:\\BigDataScience\\Document/positive/H (8).jpg',
#  'D:\\BigDataScience\\Document/positive/H (9).jpg',
#  'D:\\BigDataScience\\Document/positive/I (1).jpg',
#  'D:\\BigDataScience\\Document/positive/I (10).jpg',
#  'D:\\BigDataScience\\Document/positive/I (11).jpg',
#  'D:\\BigDataScience\\Document/positive/I (12).jpg',
#  'D:\\BigDataScience\\Document/positive/I (13).jpg',
#  'D:\\BigDataScience\\Document/positive/I (14).jpg',
#  'D:\\BigDataScience\\Document/positive/I (15).jpg',
#  'D:\\BigDataScience\\Document/positive/I (16).jpg',
#  'D:\\BigDataScience\\Document/positive/I (17).jpg',
#  'D:\\BigDataScience\\Document/positive/I (18).jpg',
#  'D:\\BigDataScience\\Document/positive/I (19).jpg',
#  'D:\\BigDataScience\\Document/positive/I (2).jpg',
#  'D:\\BigDataScience\\Document/positive/I (20).jpg',
#  'D:\\BigDataScience\\Document/positive/I (21).jpg',
#  'D:\\BigDataScience\\Document/positive/I (22).jpg',
#  'D:\\BigDataScience\\Document/positive/I (23).jpg',
#  'D:\\BigDataScience\\Document/positive/I (24).jpg',
#  'D:\\BigDataScience\\Document/positive/I (25).jpg',
#  'D:\\BigDataScience\\Document/positive/I (26).jpg',
#  'D:\\BigDataScience\\Document/positive/I (27).jpg',
#  'D:\\BigDataScience\\Document/positive/I (28).jpg',
#  'D:\\BigDataScience\\Document/positive/I (29).jpg',
#  'D:\\BigDataScience\\Document/positive/I (3).jpg',
#  'D:\\BigDataScience\\Document/positive/I (30).jpg',
#  'D:\\BigDataScience\\Document/positive/I (31).jpg',
#  'D:\\BigDataScience\\Document/positive/I (32).jpg',
#  'D:\\BigDataScience\\Document/positive/I (4).jpg',
#  'D:\\BigDataScience\\Document/positive/I (5).jpg',
#  'D:\\BigDataScience\\Document/positive/I (6).jpg',
#  'D:\\BigDataScience\\Document/positive/I (7).jpg',
#  'D:\\BigDataScience\\Document/positive/I (8).jpg',
#  'D:\\BigDataScience\\Document/positive/I (9).jpg',
#  'D:\\BigDataScience\\Document/positive/J (1).jpg',
#  'D:\\BigDataScience\\Document/positive/J (10).jpg',
#  'D:\\BigDataScience\\Document/positive/J (11).jpg',
#  'D:\\BigDataScience\\Document/positive/J (12).jpg',
#  'D:\\BigDataScience\\Document/positive/J (13).jpg',
#  'D:\\BigDataScience\\Document/positive/J (14).jpg',
#  'D:\\BigDataScience\\Document/positive/J (15).jpg',
#  'D:\\BigDataScience\\Document/positive/J (16).jpg',
#  'D:\\BigDataScience\\Document/positive/J (17).jpg',
#  'D:\\BigDataScience\\Document/positive/J (18).jpg',
#  'D:\\BigDataScience\\Document/positive/J (19).jpg',
#  'D:\\BigDataScience\\Document/positive/J (2).jpg',
#  'D:\\BigDataScience\\Document/positive/J (20).jpg',
#  'D:\\BigDataScience\\Document/positive/J (21).jpg',
#  'D:\\BigDataScience\\Document/positive/J (22).jpg',
#  'D:\\BigDataScience\\Document/positive/J (23).jpg',
#  'D:\\BigDataScience\\Document/positive/J (24).jpg',
#  'D:\\BigDataScience\\Document/positive/J (25).jpg',
#  'D:\\BigDataScience\\Document/positive/J (26).jpg',
#  'D:\\BigDataScience\\Document/positive/J (27).jpg',
#  'D:\\BigDataScience\\Document/positive/J (28).jpg',
#  'D:\\BigDataScience\\Document/positive/J (29).jpg',
#  'D:\\BigDataScience\\Document/positive/J (3).jpg',
#  'D:\\BigDataScience\\Document/positive/J (30).jpg',
#  'D:\\BigDataScience\\Document/positive/J (31).jpg',
#  'D:\\BigDataScience\\Document/positive/J (32).jpg',
#  'D:\\BigDataScience\\Document/positive/J (4).jpg',
#  'D:\\BigDataScience\\Document/positive/J (5).jpg',
#  'D:\\BigDataScience\\Document/positive/J (6).jpg',
#  'D:\\BigDataScience\\Document/positive/J (7).jpg',
#  'D:\\BigDataScience\\Document/positive/J (8).jpg',
#  'D:\\BigDataScience\\Document/positive/J (9).jpg']

# %%
def preprocess_image(filename):
    """
    Load the specified file as a JPEG image, preprocess it and
    resize it to the target shape.
    """

    image_string = tf.io.read_file(filename)
    image = tf.image.decode_jpeg(image_string, channels=3)
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, target_shape)
    return image


def preprocess_triplets(anchor, positive, negative):
    """
    Given the filenames corresponding to the three images, load and
    preprocess them.
    """

    return (
        preprocess_image(anchor),
        preprocess_image(positive),
        preprocess_image(negative),
    )

# %%
# We need to make sure both the anchor and positive images are loaded in
# sorted order so we can match them together.
anchor_images = sorted([str(anchor_images_path +'/'+ f) for f in os.listdir(anchor_images_path)])

positive_images = sorted(
    [str(positive_images_path +'/'+ f) for f in os.listdir(positive_images_path)]
)

image_count = len(anchor_images)

anchor_dataset = tf.data.Dataset.from_tensor_slices(anchor_images)
positive_dataset = tf.data.Dataset.from_tensor_slices(positive_images)

# To generate the list of negative images, let's randomize the list of
# available images and concatenate them together.
rng = np.random.RandomState(seed=42)
rng.shuffle(anchor_images)
rng.shuffle(positive_images)

negative_images = anchor_images + positive_images
np.random.RandomState(seed=32).shuffle(negative_images)

negative_dataset = tf.data.Dataset.from_tensor_slices(negative_images)
negative_dataset = negative_dataset.shuffle(buffer_size=4096)

dataset = tf.data.Dataset.zip((anchor_dataset, positive_dataset, negative_dataset))
dataset = dataset.shuffle(buffer_size=1024)
dataset = dataset.map(preprocess_triplets)

# Let's now split our dataset in train and validation.
train_dataset = dataset.take(round(image_count * 0.8))
val_dataset = dataset.skip(round(image_count * 0.8))

train_dataset = train_dataset.batch(32, drop_remainder=False)
train_dataset = train_dataset.prefetch(8)

val_dataset = val_dataset.batch(32, drop_remainder=False)
val_dataset = val_dataset.prefetch(8)

# %%
def visualize(anchor, positive, negative):
    """Visualize a few triplets from the supplied batches."""

    def show(ax, image):
        ax.imshow(image)
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    fig = plt.figure(figsize=(15, 15))

    axs = fig.subplots(3, 3)
    for i in range(3):
        show(axs[i, 0], anchor[i])
        show(axs[i, 1], positive[i])
        show(axs[i, 2], negative[i])


visualize(*list(train_dataset.take(1).as_numpy_iterator())[0])

# %%
base_cnn = vgg16.VGG16(
    weights="imagenet", input_shape=target_shape + (3,), include_top=False
)

flatten = layers.Flatten()(base_cnn.output)
dense1 = layers.Dense(256, activation="relu")(flatten)
dense1 = layers.BatchNormalization()(dense1)
dense2 = layers.Dense(256, activation="relu")(dense1)
dense2 = layers.BatchNormalization()(dense2)
output = layers.Dense(256)(dense2)

embedding = Model(base_cnn.input, output, name="Embedding")

# %% [markdown]
# embedding.load_weights('twin.h5')

# %%
trainable = False
for layer in base_cnn.layers:
    if layer.name == "conv5_block1_out":
        trainable = True
    layer.trainable = trainable

# %%
class DistanceLayer(layers.Layer):
    """
    This layer is responsible for computing the distance between the anchor
    embedding and the positive embedding, and the anchor embedding and the
    negative embedding.
    """

    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def call(self, anchor, positive, negative):
        ap_distance = tf.reduce_sum(tf.square(anchor - positive), -1)
        an_distance = tf.reduce_sum(tf.square(anchor - negative), -1)
        return (ap_distance, an_distance)


anchor_input = layers.Input(name="anchor", shape=target_shape + (3,))
positive_input = layers.Input(name="positive", shape=target_shape + (3,))
negative_input = layers.Input(name="negative", shape=target_shape + (3,))

distances = DistanceLayer()(
    embedding(vgg16.preprocess_input(anchor_input)),
    embedding(vgg16.preprocess_input(positive_input)),
    embedding(vgg16.preprocess_input(negative_input)),
)

siamese_network = Model(
    inputs=[anchor_input, positive_input, negative_input], outputs=distances
)

# %%
class SiameseModel(Model):
    """The Siamese Network model with a custom training and testing loops.

    Computes the triplet loss using the three embeddings produced by the
    Siamese Network.

    The triplet loss is defined as:
       L(A, P, N) = max(‖f(A) - f(P)‖² - ‖f(A) - f(N)‖² + margin, 0)
    """

    def __init__(self, siamese_network, margin=0.5):
        super(SiameseModel, self).__init__()
        self.siamese_network = siamese_network
        self.margin = margin
        self.loss_tracker = metrics.Mean(name="loss")

    def call(self, inputs):
        return self.siamese_network(inputs)

    def train_step(self, data):
        # GradientTape is a context manager that records every operation that
        # you do inside. We are using it here to compute the loss so we can get
        # the gradients and apply them using the optimizer specified in
        # `compile()`.
        with tf.GradientTape() as tape:
            loss = self._compute_loss(data)

        # Storing the gradients of the loss function with respect to the
        # weights/parameters.
        gradients = tape.gradient(loss, self.siamese_network.trainable_weights)

        # Applying the gradients on the model using the specified optimizer
        self.optimizer.apply_gradients(
            zip(gradients, self.siamese_network.trainable_weights)
        )

        # Let's update and return the training loss metric.
        self.loss_tracker.update_state(loss)
        return {"loss": self.loss_tracker.result()}

    def test_step(self, data):
        loss = self._compute_loss(data)

        # Let's update and return the loss metric.
        self.loss_tracker.update_state(loss)
        return {"loss": self.loss_tracker.result()}

    def _compute_loss(self, data):
        # The output of the network is a tuple containing the distances
        # between the anchor and the positive example, and the anchor and
        # the negative example.
        ap_distance, an_distance = self.siamese_network(data)

        # Computing the Triplet Loss by subtracting both distances and
        # making sure we don't get a negative value.
        loss = ap_distance - an_distance
        loss = tf.maximum(loss + self.margin, 0.0)
        return loss

    @property
    def metrics(self):
        # We need to list our metrics here so the `reset_states()` can be
        # called automatically.
        return [self.loss_tracker]

# %%
siamese_network.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# anchor (InputLayer)             [(None, 96, 96, 3)]  0
# __________________________________________________________________________________________________
# negative (InputLayer)           [(None, 96, 96, 3)]  0
# __________________________________________________________________________________________________
# positive (InputLayer)           [(None, 96, 96, 3)]  0
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice (Tens [(None, 96, 96, 3)]  0           anchor[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_2 (Te [(None, 96, 96, 3)]  0           negative[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_1 (Te [(None, 96, 96, 3)]  0           positive[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_BiasAdd (TensorFlow [(None, 96, 96, 3)]  0           tf_op_layer_strided_slice[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_BiasAdd_2 (TensorFl [(None, 96, 96, 3)]  0           tf_op_layer_strided_slice_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_BiasAdd_1 (TensorFl [(None, 96, 96, 3)]  0           tf_op_layer_strided_slice_1[0][0]
# __________________________________________________________________________________________________
# Embedding (Model)               (None, 256)          16028224    tf_op_layer_BiasAdd[0][0]
#                                                                  tf_op_layer_BiasAdd_1[0][0]
#                                                                  tf_op_layer_BiasAdd_2[0][0]
# __________________________________________________________________________________________________
# distance_layer (DistanceLayer)  ((None,), (None,))   0           Embedding[1][0]
# ==================================================================================================
# Total params: 16,028,224
# Trainable params: 1,312,512
# Non-trainable params: 14,715,712
# __________________________________________________________________________________________________

# %%
siamese_model = SiameseModel(siamese_network)
siamese_model.compile(optimizer=optimizers.Adam(0.0001))

# %%
history = siamese_model.fit(train_dataset, epochs=50, validation_data=val_dataset)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.7468 - val_loss: 0.7276
# Epoch 2/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.5727 - val_loss: 0.4072
# Epoch 3/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.5125 - val_loss: 0.4048
# Epoch 4/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.4906 - val_loss: 0.4221
# Epoch 5/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.4609 - val_loss: 0.4425
# Epoch 6/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.4326 - val_loss: 0.4439
# Epoch 7/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.4309 - val_loss: 0.4190
# Epoch 8/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.4436 - val_loss: 0.4594
# Epoch 9/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.4332 - val_loss: 0.3074
# Epoch 10/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.4130 - val_loss: 0.4156
# Epoch 11/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.4060 - val_loss: 0.3221
# Epoch 12/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3517 - val_loss: 0.4312
# Epoch 13/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3634 - val_loss: 0.3313
# Epoch 14/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3589 - val_loss: 0.3456
# Epoch 15/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3944 - val_loss: 0.2970
# Epoch 16/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3347 - val_loss: 0.3715
# Epoch 17/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3801 - val_loss: 0.3798
# Epoch 18/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3596 - val_loss: 0.3137
# Epoch 19/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.3747 - val_loss: 0.3672
# Epoch 20/50
# 8/8 [==============================] - 43s 5s/step - loss: 0.3757 - val_loss: 0.2836
# Epoch 21/50
# 8/8 [==============================] - 43s 5s/step - loss: 0.3789 - val_loss: 0.3400
# Epoch 22/50
# 8/8 [==============================] - 44s 6s/step - loss: 0.3755 - val_loss: 0.3747
# Epoch 23/50
# 8/8 [==============================] - 43s 5s/step - loss: 0.3605 - val_loss: 0.3068
# Epoch 24/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3053 - val_loss: 0.3796
# Epoch 25/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3408 - val_loss: 0.3370
# Epoch 26/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3564 - val_loss: 0.3266
# Epoch 27/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3371 - val_loss: 0.3009
# Epoch 28/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3215 - val_loss: 0.3010
# Epoch 29/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3520 - val_loss: 0.3440
# Epoch 30/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.3138 - val_loss: 0.3293
# Epoch 31/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3177 - val_loss: 0.2645
# Epoch 32/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3338 - val_loss: 0.3048
# Epoch 33/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3341 - val_loss: 0.2477
# Epoch 34/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3217 - val_loss: 0.3004
# Epoch 35/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3239 - val_loss: 0.3754
# Epoch 36/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3262 - val_loss: 0.2753
# Epoch 37/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3220 - val_loss: 0.3476
# Epoch 38/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3126 - val_loss: 0.3077
# Epoch 39/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.2994 - val_loss: 0.3697
# Epoch 40/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3088 - val_loss: 0.3572
# Epoch 41/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3007 - val_loss: 0.2771
# Epoch 42/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3017 - val_loss: 0.3540
# Epoch 43/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3014 - val_loss: 0.2496
# Epoch 44/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3010 - val_loss: 0.3072
# Epoch 45/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3046 - val_loss: 0.2755
# Epoch 46/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3072 - val_loss: 0.3018
# Epoch 47/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3107 - val_loss: 0.3118
# Epoch 48/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2927 - val_loss: 0.3092
# Epoch 49/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3123 - val_loss: 0.3185
# Epoch 50/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.3012 - val_loss: 0.3115

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.grid()
plt.legend(['training loss', 'validation loss'], loc='upper right')
plt.show()

# %%
history = siamese_model.fit(train_dataset, epochs=50, validation_data=val_dataset)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.2422 - val_loss: 0.1768
# Epoch 2/50
# 8/8 [==============================] - 43s 5s/step - loss: 0.2435 - val_loss: 0.2147
# Epoch 3/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2421 - val_loss: 0.2281
# Epoch 4/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.2446 - val_loss: 0.1882
# Epoch 5/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.2333 - val_loss: 0.2536
# Epoch 6/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.2386 - val_loss: 0.2058
# Epoch 7/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2156 - val_loss: 0.3063
# Epoch 8/50
# 8/8 [==============================] - 43s 5s/step - loss: 0.2110 - val_loss: 0.2134
# Epoch 9/50
# 8/8 [==============================] - 43s 5s/step - loss: 0.2303 - val_loss: 0.1894
# Epoch 10/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2306 - val_loss: 0.2809
# Epoch 11/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2232 - val_loss: 0.3037
# Epoch 12/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2334 - val_loss: 0.1626
# Epoch 13/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.2455 - val_loss: 0.2100
# Epoch 14/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2383 - val_loss: 0.2191
# Epoch 15/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2526 - val_loss: 0.2448
# Epoch 16/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2447 - val_loss: 0.2031
# Epoch 17/50
# 8/8 [==============================] - 43s 5s/step - loss: 0.2095 - val_loss: 0.2254
# Epoch 18/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2148 - val_loss: 0.2009
# Epoch 19/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.1855 - val_loss: 0.2083
# Epoch 20/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2521 - val_loss: 0.2363
# Epoch 21/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2577 - val_loss: 0.2339
# Epoch 22/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.2195 - val_loss: 0.1902
# Epoch 23/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.2276 - val_loss: 0.2395
# Epoch 24/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2187 - val_loss: 0.4062
# Epoch 25/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2138 - val_loss: 0.2482
# Epoch 26/50
# 8/8 [==============================] - 43s 5s/step - loss: 0.1995 - val_loss: 0.2510
# Epoch 27/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2660 - val_loss: 0.2167
# Epoch 28/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2407 - val_loss: 0.1912
# Epoch 29/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.2566 - val_loss: 0.2328
# Epoch 30/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2163 - val_loss: 0.2002
# Epoch 31/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2312 - val_loss: 0.2185
# Epoch 32/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2207 - val_loss: 0.1798
# Epoch 33/50
# 8/8 [==============================] - 44s 5s/step - loss: 0.2337 - val_loss: 0.1889
# Epoch 34/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.2403 - val_loss: 0.2134
# Epoch 35/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.2311 - val_loss: 0.2181
# Epoch 36/50
# 8/8 [==============================] - 43s 5s/step - loss: 0.2161 - val_loss: 0.2328
# Epoch 37/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2309 - val_loss: 0.1871
# Epoch 38/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2286 - val_loss: 0.2825
# Epoch 39/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2238 - val_loss: 0.2191
# Epoch 40/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.2346 - val_loss: 0.2334
# Epoch 41/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.2253 - val_loss: 0.2118
# Epoch 42/50
# 8/8 [==============================] - 41s 5s/step - loss: 0.2156 - val_loss: 0.1764
# Epoch 43/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2230 - val_loss: 0.2637
# Epoch 44/50
# 8/8 [==============================] - 43s 5s/step - loss: 0.2258 - val_loss: 0.2557
# Epoch 45/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.1957 - val_loss: 0.2400
# Epoch 46/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2713 - val_loss: 0.1892
# Epoch 47/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2346 - val_loss: 0.2075
# Epoch 48/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2217 - val_loss: 0.1980
# Epoch 49/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.1924 - val_loss: 0.2686
# Epoch 50/50
# 8/8 [==============================] - 42s 5s/step - loss: 0.2347 - val_loss: 0.2035

# %%
embedding.save('twin_partial_96_3.h5')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.grid()
plt.legend(['training loss', 'validation loss'], loc='upper right')
plt.show()

# %%
sample = next(iter(train_dataset))
visualize(*sample)

anchor, positive, negative = sample
anchor_embedding, positive_embedding, negative_embedding = (
    embedding(vgg16.preprocess_input(anchor)),
    embedding(vgg16.preprocess_input(positive)),
    embedding(vgg16.preprocess_input(negative)),
)

# %%
cosine_similarity = metrics.CosineSimilarity()

positive_similarity = cosine_similarity(anchor_embedding, positive_embedding)
print("Positive similarity:", positive_similarity.numpy())

negative_similarity = cosine_similarity(anchor_embedding, negative_embedding)
print("Negative similarity", negative_similarity.numpy())

# %%
embedding.save('twin_partial_96.h5')
